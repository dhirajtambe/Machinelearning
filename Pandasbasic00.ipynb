# %% [markdown]
# <a href="https://colab.research.google.com/github/dhirajtambe/Machinelearning/blob/main/Pandasbasic00.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## **Pandas Basic functions**

# %%
import pandas as pd

# %%
df=pd.read_csv("/content/Movie-Ratings analysis.csv")

# %%
df.head(11)
# Out:
#                      Film      Genre  Rotten Tomatoes Ratings %  \
# 0   (500) Days of Summer      Comedy                         87
# 1             10,000 B.C.  Adventure                          9
# 2              12 Rounds      Action                         30
# 3               127 Hours  Adventure                         93
# 4               17 Again      Comedy                         55
# 5                    2012     Action                         39
# 6              27 Dresses     Comedy                         40
# 7        30 Days of Night     Horror                         50
# 8      30 Minutes or Less     Comedy                         43
# 9                   50/50     Comedy                         93
# 10             88 Minutes      Drama                          5
#
#     Audience Ratings %  Budget (million $)  Year of release
# 0                   81                   8             2009
# 1                   44                 105             2008
# ...

# %%
df.tail(10)
# Out:
#                                    Film     Genre  Rotten Tomatoes Ratings %  \
# 549                             Yes Man    Comedy                         43
# 550                           Yogi Bear    Comedy                         14
# 551                           You Again    Comedy                         18
# 552       You Don't Mess with the Zohan    Comedy                         36
# 553  You Will Meet a Tall Dark Stranger    Comedy                         43
# 554                       Your Highness    Comedy                         26
# 555                     Youth in Revolt    Comedy                         68
# 556                              Zodiac  Thriller                         89
# 557                         Zombieland     Action                         90
# 558                           Zookeeper    Comedy                         14
#
#      Audience Ratings %  Budget (million $)  Year of release
# 549                  72                  70             2008
# ...

# %%
df.dtypes
# Out:
# Film                         object
# Genre                        object
# Rotten Tomatoes Ratings %     int64
# Audience Ratings %            int64
# Budget (million $)            int64
# Year of release               int64
# dtype: object

# %%
df.columns
# Out:
# Index(['Film', 'Genre', 'Rotten Tomatoes Ratings %', 'Audience Ratings %',
#        'Budget (million $)', 'Year of release'],
#       dtype='object')

# %%
df.axes
# Out:
# [RangeIndex(start=0, stop=559, step=1),
#  Index(['Film', 'Genre', 'Rotten Tomatoes Ratings %', 'Audience Ratings %',
#         'Budget (million $)', 'Year of release'],
#        dtype='object')]

# %%
df.ndim
# Out:
# 2

# %%
df.size
# Out:
# 3354

# %%
df.shape
# Out:
# (559, 6)

# %%
df.values
# Out:
# array([['(500) Days of Summer ', 'Comedy', 87, 81, 8, 2009],
#        ['10,000 B.C.', 'Adventure', 9, 44, 105, 2008],
#        ['12 Rounds ', 'Action', 30, 52, 20, 2009],
#        ...,
#        ['Zodiac', 'Thriller', 89, 73, 65, 2007],
#        ['Zombieland ', 'Action', 90, 87, 24, 2009],
#        ['Zookeeper', 'Comedy', 14, 42, 80, 2011]], dtype=object)

# %%
df.describe()
# Out:
#        Rotten Tomatoes Ratings %  Audience Ratings %  Budget (million $)  \
# count                 559.000000          559.000000          559.000000
# mean                   47.309481           58.744186           50.236136
# std                    26.413091           16.826887           48.731817
# min                     0.000000            0.000000            0.000000
# 25%                    25.000000           47.000000           20.000000
# 50%                    46.000000           58.000000           35.000000
# 75%                    70.000000           72.000000           65.000000
# max                    97.000000           96.000000          300.000000
#
#        Year of release
# count       559.000000
# mean       2009.152057
# std           1.362632
# min        2007.000000
# 25%        2008.000000
# 50%        2009.000000
# 75%        2010.000000
# max        2011.000000

# %%
df.max()
# Out:
# Film                         Zookeeper
# Genre                         Thriller
# Rotten Tomatoes Ratings %           97
# Audience Ratings %                  96
# Budget (million $)                 300
# Year of release                   2011
# dtype: object

# %%
df.min()
# Out:
# Film                         (500) Days of Summer
# Genre                                       Action
# Rotten Tomatoes Ratings %                        0
# Audience Ratings %                               0
# Budget (million $)                               0
# Year of release                               2007
# dtype: object

# %%
df.std()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   """Entry point for launching an IPython kernel.
# Rotten Tomatoes Ratings %    26.413091
# Audience Ratings %           16.826887
# Budget (million $)           48.731817
# Year of release               1.362632
# dtype: float64

# %%
df.sample(15)
# Out:
#                              Film      Genre  Rotten Tomatoes Ratings %  \
# 455                   The Muppets     Comedy                         97
# 483  The Twilight Saga: Eclipse\t      Drama                         50
# 68              College Road Trip  Adventure                         13
# 340            Sex and the City 2     Comedy                         15
# 337                      Semi-Pro     Comedy                         21
# 438                   The Joneses     Comedy                         61
# 21           Aliens in the Attic   Adventure                         30
# 476                    The Switch     Comedy                         52
# 338                  Seven Pounds      Drama                         27
# 533               We Bought a Zoo     Comedy                         63
# 412                     The Eagle     Action                         39
# 530                       Warrior     Action                         83
# ...

# %%
df_sub=df['Film']
df_sub
# Out:
# 0      (500) Days of Summer
# 1                10,000 B.C.
# 2                 12 Rounds
# 3                  127 Hours
# 4                  17 Again
#                ...
# 554            Your Highness
# 555          Youth in Revolt
# 556                   Zodiac
# 557              Zombieland
# 558                Zookeeper
# Name: Film, Length: 559, dtype: object

# %%
df.Genre
# Out:
# 0         Comedy
# 1      Adventure
# 2         Action
# 3      Adventure
# 4         Comedy
#          ...
# 554       Comedy
# 555       Comedy
# 556     Thriller
# 557       Action
# 558       Comedy
# Name: Genre, Length: 559, dtype: object

# %%
df[["Genre"]]
# Out:
#          Genre
# 0       Comedy
# 1    Adventure
# 2       Action
# 3    Adventure
# 4       Comedy
# ..         ...
# 554     Comedy
# 555     Comedy
# 556   Thriller
# 557     Action
# 558     Comedy
#
# [559 rows x 1 columns]

# %%
df["Year of release"] > 2007
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
#        ...
# 554     True
# 555     True
# 556    False
# 557     True
# 558     True
# Name: Year of release, Length: 559, dtype: bool

# %%
df[["Year of release"]] > 2007
# Out:
#      Year of release
# 0               True
# 1               True
# 2               True
# 3               True
# 4               True
# ..               ...
# 554             True
# 555             True
# 556            False
# 557             True
# 558             True
#
# [559 rows x 1 columns]

# %%
df.iloc[0]
# Out:
# Film                         (500) Days of Summer
# Genre                                       Comedy
# Rotten Tomatoes Ratings %                       87
# Audience Ratings %                              81
# Budget (million $)                               8
# Year of release                               2009
# Name: 0, dtype: object

# %%
df.iloc[0:7]
# Out:
#                     Film      Genre  Rotten Tomatoes Ratings %  \
# 0  (500) Days of Summer      Comedy                         87
# 1            10,000 B.C.  Adventure                          9
# 2             12 Rounds      Action                         30
# 3              127 Hours  Adventure                         93
# 4              17 Again      Comedy                         55
# 5                   2012     Action                         39
# 6             27 Dresses     Comedy                         40
#
#    Audience Ratings %  Budget (million $)  Year of release
# 0                  81                   8             2009
# 1                  44                 105             2008
# 2                  52                  20             2009
# 3                  84                  18             2010
# 4                  70                  20             2009
# 5                  63                 200             2009
# ...

# %%
df.iloc[:,1:7]
# Out:
#          Genre  Rotten Tomatoes Ratings %  Audience Ratings %  \
# 0       Comedy                         87                  81
# 1    Adventure                          9                  44
# 2       Action                         30                  52
# 3    Adventure                         93                  84
# 4       Comedy                         55                  70
# ..         ...                        ...                 ...
# 554     Comedy                         26                  36
# 555     Comedy                         68                  52
# 556   Thriller                         89                  73
# 557     Action                         90                  87
# 558     Comedy                         14                  42
#
#      Budget (million $)  Year of release
# 0                     8             2009
# 1                   105             2008
# 2                    20             2009
# 3                    18             2010
# ...

# %%
df.iloc[[0,4],[3,4]]
# Out:
#    Audience Ratings %  Budget (million $)
# 0                  81                   8
# 4                  70                  20

# %%
df[["Audience Ratings %","Budget (million $)"]].agg(['min','mean','max'])
# Out:
#       Audience Ratings %  Budget (million $)
# min             0.000000            0.000000
# mean           58.744186           50.236136
# max            96.000000          300.000000

# %%
df.describe()
# Out:
#        Rotten Tomatoes Ratings %  Audience Ratings %  Budget (million $)  \
# count                 559.000000          559.000000          559.000000
# mean                   47.309481           58.744186           50.236136
# std                    26.413091           16.826887           48.731817
# min                     0.000000            0.000000            0.000000
# 25%                    25.000000           47.000000           20.000000
# 50%                    46.000000           58.000000           35.000000
# 75%                    70.000000           72.000000           65.000000
# max                    97.000000           96.000000          300.000000
#
#        Year of release
# count       559.000000
# mean       2009.152057
# std           1.362632
# min        2007.000000
# 25%        2008.000000
# 50%        2009.000000
# 75%        2010.000000
# max        2011.000000

# %%
df.skew()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   """Entry point for launching an IPython kernel.
# Rotten Tomatoes Ratings %    0.128471
# Audience Ratings %          -0.095393
# Budget (million $)           1.914432
# Year of release             -0.089280
# dtype: float64

# %%
df.kurt()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   """Entry point for launching an IPython kernel.
# Rotten Tomatoes Ratings %   -1.132768
# Audience Ratings %          -0.391891
# Budget (million $)           3.939843
# Year of release             -1.226892
# dtype: float64
